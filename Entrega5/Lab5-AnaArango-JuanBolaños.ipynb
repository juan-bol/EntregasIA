# %%
from pyknow import *

# %% [markdown]
# Las reglas a pasar de .drl a python están en https://github.com/kmilichus/AgroTIC/blob/master/ExpertoFertilizacion/src/main/resources/reglas.drl

# %%
class AnalisisDeSuelo(Fact):
    pass

# %%
class AgroTIC(KnowledgeEngine):
    
    # Initial Facts
    @DefFacts()
    def _initial_action(self):
        yield AnalisisDeSuelo(ph=6.5, CE=1, PH='ALCALINO', arcilla=50, arena=60, limo=50)

    @Rule(AnalisisDeSuelo(ph=P(lambda ph: ph>=7.2)))
    def rule0(self):
        print("\nRule 0:")
        print("==> ph: ALCALINO")    
    
    @Rule(AnalisisDeSuelo(ph=P(lambda ph: 6.8<ph<7.2)))
    def rule1(self):
        print("\nRule 1:")
        print("==> ph: LIGERAMENTE ALCALINO") 
        
    @Rule(AnalisisDeSuelo(ph=P(lambda ph: 6.2<=ph<=6.8)))
    def rule2(self):
        print("\nRule 2:")
        print("==> ph: NEUTRO") 
    
    @Rule(AnalisisDeSuelo(ph=P(lambda ph: 6.5<ph<6.2)))
    def rule3(self):
        print("\nRule 3:")
        print("==> ph: LIGERAMENTE ACIDO")
    
    @Rule(AnalisisDeSuelo(ph=P(lambda ph: ph<=5.6)))
    def rule4(self):
        print("\nRule 4:")
        print("==> ph: ACIDO")
    
    @Rule(AnalisisDeSuelo(CE=P(lambda CE: CE<0.8)))
    def rule5(self):
        print("\nRule 5:")
        print("==> conductividadElectrica: BAJA") 
        
    @Rule(AnalisisDeSuelo(CE=P(lambda CE: CE>=0.8)))
    def rule6(self):
        print("\nRule 6:")
        print("==> conductividadElectrica: ALTA") 
        
    @Rule(AnalisisDeSuelo(PH= L('ALCALINO')))
    def rule7(self):
        print("\nRule 7")
        print("==> ExtractoSoluble: True")
        
    @Rule(AnalisisDeSuelo(PH=L('LIGERAMENTE ALCALINO')))
    def rule8(self):
        print("\nRule 8:")
        print("==> ExtractoSoluble: True")
        
    ## A partir de aquí, en cada regla se hace un 'Fire Rule ...' no se cómo hacerlo en python o si no sea necesario TODO
    
    @Rule(AnalisisDeSuelo(arcilla=P(lambda arcilla: arcilla>=40), PH=L('ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule9(self):
        print("\nRule 9:")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases");   
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos")
        
        
    @Rule(AnalisisDeSuelo(arena=P(lambda arena: arena>=50), PH=L('ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule10(self):
        print("\nRule 10:")
        print("     |-(1) Revisar las mediciones realizadas.")
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo:limo>=45), PH=L('ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule11(self):
        print("\nRule 11:")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena=P(lambda arena: arena<=40), 
                          arcilla=P(lambda arcilla: arcilla>=40), PH=L('ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule12(self):
        print("\nRule 12:")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
    
    @Rule(AnalisisDeSuelo(arcilla=P(lambda arcilla: arcilla>=40), PH=L('ALCALINO'), CE=P(lambda CE: CE<0.8)))
    def rule13(self):
        print("\nRule 13:")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")  
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos")
        print("     |-(5) Baja disponibilidad de elementos menores")
        
    @Rule(AnalisisDeSuelo(arena=P(lambda arena: arena>=50), PH=L('ALCALINO'), CE=P(lambda CE: CE<0.8)))
    def rule14(self):
        print("\nRule 14:")
        print("     |-(1) Revisar las mediciones realizadas.")
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo:limo>=45), PH=L('ALCALINO'), CE=P(lambda CE: CE<0.8)))
    def rule15(self):
        print("\nRule 15:")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(5) Baja disponibilidad de elementos menores ")
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena=P(lambda arena: arena<=40), 
                          arcilla=P(lambda arcilla: arcilla<=40), PH=L('ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule16(self):
        print("\nRule 16:")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        print("     |-(3) Baja disponibilidad de elementos menores ")
        
    @Rule(AnalisisDeSuelo(arcilla=P(lambda arcilla: arcilla>=40), PH=L('LIGERAMENTE ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule17(self):
        print("\nRule 17:")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases") 
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos")
        print("     |-(5) Alta saturación de calcio")
        print("     |-(6) Salinidad en el suelo")
        print("     |-(7) Baja disponibilidad de Fosforo (Precipitación)")
    
    @Rule(AnalisisDeSuelo(arena=P(lambda arena: arena>=50), PH=L('LIGERAMENTE ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule18(self):
        print("\nRule 18:")
        print("     |-(1) Revisar las mediciones realizadas.")
    
    @Rule(AnalisisDeSuelo(limo=P(lambda limo:limo>=45), PH=L('LIGERAMENTE ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule19(self):
        print("\nRule 19:")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena=P(lambda arena: arena<=40), 
                          arcilla=P(lambda arcilla: arcilla<=40), PH=L('LIGERAMENTE ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule20(self):
        print("\nRule 20:")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
    
    @Rule(AnalisisDeSuelo(arcilla=P(lambda arcilla: arcilla>=40), PH=L('LIGERAMENTE ALCALINO'), CE=P(lambda CE: CE<0.8)))
    def rule21(self):
        print("\nRule 21:")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases") 
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos")
        print("     |-(5) Baja disponibilidad de elementos menores")
        
    @Rule(AnalisisDeSuelo(arena=P(lambda arena: arena>=50), PH=L('LIGERAMENTE ALCALINO'), CE=P(lambda CE: CE<0.8)))
    def rule22(self):
        print("\nRule 22:")
        print("     |-(1) Revisar las mediciones realizadas.")
        
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo:limo>=45), PH=L('LIGERAMENTE ALCALINO'), CE=P(lambda CE: CE<0.8)))
    def rule23(self):
        print("\nRule 23:")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(5) Baja disponibilidad de elementos menores")
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena=P(lambda arena: arena<=40), 
                          arcilla=P(lambda arcilla: arcilla<=40), PH=L('LIGERAMENTE ALCALINO'), CE=P(lambda CE: CE>=0.8)))
    def rule24(self):
        print("\nRule 24:")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        print("     |-(3) Baja disponibilidad de elementos menores")
        
        
    @Rule(AnalisisDeSuelo(arcilla=P(lambda arcilla: arcilla>=40), PH=L('NEUTRO'), CE=P(lambda CE: CE>=0.8)))
    def rule25(self):
        print("\nRule 25:")
        print("     |-(1) Baja mineralizacion de MO (Baja actvidad microbiologica)")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Salinidad en el suelo")
        
    @Rule(AnalisisDeSuelo(arena=P(lambda arena: arena>=50), PH=L('NEUTRO'), CE=P(lambda CE: CE>=0.8)))
    def rule26(self):
        print("\nRule 26:")
        print("     |-(1) Revisar las mediciones realizadas.")
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo:limo>=45), PH=L('NEUTRO'), CE=P(lambda CE: CE>=0.8)))
    def rule27(self):
        print("\nRule 27:")
        print("     |-(1) Sanilidad en el suelo")
    
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena=P(lambda arena: arena<=40), 
                          arcilla=P(lambda arcilla: arcilla<=40), PH=L('NEUTRO'), CE=P(lambda CE: CE>=0.8)))
    def rule28(self):
        print("\nRule 28:")
        
    @Rule(AnalisisDeSuelo(arcilla=P(lambda arcilla: arcilla>=40), PH=L('NEUTRO'), CE=P(lambda CE: CE<0.8)))
    def rule25(self):
        print("\nRule 25:")
        print("     |-(1) Baja mineralizacion de MO (Baja actvidad microbiologica)")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Limitaciones de movimiento de agua")
        
    @Rule(AnalisisDeSuelo(arena=P(lambda arena: arena>=50), PH=L('NEUTRO'), CE=P(lambda CE: CE<0.8)))
    def rule30(self):
        print("\nRule 30:")
        print("     |-(1) Revisar las mediciones realizadas.")
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo>=45), PH=L('NEUTRO'), CE=P(lambda CE: CE<0.8)))
    def rule31(self):
        print("\nRule 31:")
        print("     |-(1) Coloraciones grises suelo (Glaizeado).")
        #Fire Rule : CalcularIntercambiables
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena=P(lambda arena: arena<=40), arcilla=P(lambda arcilla: arcilla<=40),PH=L('NEUTRO'), CE=P(lambda CE: CE>=0.8)))
    def rule32(self):
        print("\nRule 32:")
        #Fire Rule : CalcularIntercambiables
        
    @Rule(AnalisisDeSuelo(arcilla=P(lambda arcilla: arcilla>=40),PH=L('LIGERAMENTE ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule33(self):
        print("\nRule 33:")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos	")
        print("     |-(5) Alta saturación de calcio")
        print("     |-(6) Salinidad en el suelo")
        print("     |-(7) Baja disponibilidad de Fosforo (Precipitación)")
        #Fire Rule : CalcularIntercambiables
        #Fire Rule : Enmienda
        
    @Rule(AnalisisDeSuelo(arena=P(lambda arena: arena>=50),PH=L('LIGERAMENTE ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule34(self):
        print("\nRule 34:")
        print("     |-(1) Revisar las mediciones realizadas.")
        
            
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo>=45),PH=L('LIGERAMENTE ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule35(self):
        print("\nRule 35:")
        print("     |-(1) Contenido de Aluminio")
        print("     |-(2) Sulfatos altos")
        print("     |-(3) Impedancia")
        #Fire Rule : CalcularIntercambiables
    
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena=P(lambda arena: arena<=40), arcilla=P(lambda arcilla: arcilla<=40), PH=L('LIGERAMENTE ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule36(self):
        print("\nRule 36:")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        #Fire Rule : CalcularIntercambiables
    
    @Rule(AnalisisDeSuelo(arcilla=P(lambda arcilla: arcilla>=40), PH=L('LIGERAMENTE ACIDO'), CE=P(lambda CE: CE<0.8)))
    def rule37(self):
        print("\nRule 37:")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases") 
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos")
        print("     |-(5) Baja disponibilidad de elementos menores ")
        #Fire Rule : CalcularIntercambiables;
    
    @Rule(AnalisisDeSuelo(arena=P(lambda arena: arena>=50), PH=L('LIGERAMENTE ACIDO'), CE=P(lambda CE: CE<0.8)))
    def rule38(self):
        print("\nRule 38:")
        print("     |-(1) Revisar las mediciones realizadas.")
        
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo>=45), PH=L('LIGERAMENTE ACIDO'), CE=P(lambda CE: CE<0.8)))
    def rule39(self):
        print("\nRule 39:")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(5) Baja disponibilidad de elementos menores ")
        #Fire Rule : CalcularIntercambiables;
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena=P(lambda arena: arena<=40), arcilla=P(lambda arcilla: arcilla<=40), PH=L('LIGERAMENTE ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule40(self):
        print("\nRule 40:")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        print("     |-(3) Baja disponibilidad de elementos menores ") 
        #Fire Rule : CalcularIntercambiables;}
        
    @Rule(AnalisisDeSuelo( arcilla=P(lambda arcilla: arcilla>=40), PH=L('ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule41(self):
        print("\nRule 41:")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")  
        print("     |-(3) Acumulacion de iones alcalinoterreos")
        print("     |-(4) Salinidad en el suelo")
        print("     |-(5) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(6) Baja disponibilidad de Calcio")
        print("     |-(7) Contenido de Aluminio")
        #Fire Rule : CalcularIntercambiables
        #Fire Rule : Enmienda
        
    @Rule(AnalisisDeSuelo( arena=P(lambda arena: arena>=50), PH=L('ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule42(self):
        print("\nRule 42:")
        print("     |-(1) Revisar las mediciones realizadas.")
        
    @Rule(AnalisisDeSuelo( limo=P(lambda limo: limo>=45), PH=L('ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule43(self):
        print("\nRule 43:")
        print("     |-(1) Contenido de Aluminio")
        print("     |-(2) Sulfatos altos")  
        print("     |-(3) Impedancia")
        #Fire Rule : CalcularIntercambiables
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena =P(lambda arena: arena<=40), arcilla=P(lambda arcilla: arcilla<=40), PH=L('ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule44(self):
        print("\nRule 44:")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        #Fire Rule : CalcularIntercambiables

    @Rule(AnalisisDeSuelo(arcilla=P(lambda arcilla: arcilla>=40), PH=L('ACIDO'), CE=P(lambda CE: CE<0.8)))
    def rule45(self):
        print("\nRule 45:")
        print("     |-(1) Limitaciones de movimiento de agua")
        print("     |-(2) Baja difusion de Oxigeno y flujo de gases")    
        print("     |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica")
        print("     |-(4) Acumulacion de iones alcalinoterreos")
        print("     |-(5) Baja disponibilidad de elementos menores")
        #Fire Rule : CalcularIntercambiables
        
    @Rule(AnalisisDeSuelo(arena=P(lambda arena: arena>=50), PH=L('ACIDO'), CE=P(lambda CE: CE<0.8)))
    def rule46(self):
        print("\nRule 46:")
        print("     |-(1) Revisar las mediciones realizadas.")
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo>=45), PH=L('ACIDO'), CE=P(lambda CE: CE<0.8)))
    def rule47(self):
        print("\nRule 47:")
        print("     |-(1) Coloraciones grises suelo (Glaizeado)")
        print("     |-(2) Suelo Hidromorfico")
        print("     |-(3) Limitaciones fisicas temporales")
        print("     |-(4) Baja difusion de Oxigeno y flujo de gases")
        print("     |-(5) Baja disponibilidad de elementos menores ")
        #Fire Rule : CalcularIntercambiables
        
    @Rule(AnalisisDeSuelo(limo=P(lambda limo: limo<=40), arena=P(lambda arena: arena<=40), arcilla=P(lambda arcilla: arcilla<=40), PH=L('ACIDO'), CE=P(lambda CE: CE>=0.8)))
    def rule48(self):
        print("\nRule 48:")
        print("     |-(1) Baja disponibilidad de Fosforo (Precipitación)")
        print("     |-(2) Baja disponibilidad de Calcio")
        print("     |-(3) Baja disponibilidad de elementos menores ")
        #Fire Rule : CalcularIntercambiables

# %%
agro = AgroTIC()
agro.reset()
agro.run()
# Out:
# Rule 11:
#      |-(1) Coloraciones grises suelo (Glaizeado)
#      |-(2) Suelo Hidromorfico
#      |-(3) Limitaciones fisicas temporales
#      |-(4) Baja difusion de Oxigeno y flujo de gases
#
# Rule 9:
#      |-(1) Limitaciones de movimiento de agua
#      |-(2) Baja difusion de Oxigeno y flujo de gases
#      |-(3) Baja mineralizacion de MO (Baja actvidad microbiologica
#      |-(4) Acumulacion de iones alcalinoterreos
#
# Rule 10:
#      |-(1) Revisar las mediciones realizadas.
#
# Rule 7
# ==> ExtractoSoluble: True
#
# Rule 2:
# ==> ph: NEUTRO
#
# Rule 6:
# ==> conductividadElectrica: ALTA
